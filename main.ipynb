# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
iPhone7plus = pd.read_csv("dataset/iphone7.csv")
iPhone8 = pd.read_csv("dataset/iphone8.csv")
Note11 = pd.read_csv("dataset/android12.csv")

# %%
iPhone7plus.columns
# Out:
# Index(['Time', 'Current power/SENSOR'], dtype='object')

# %%
iPhone7plus["Time"] = pd.to_datetime(iPhone7plus["Time"])
iPhone8["Time"] = pd.to_datetime(iPhone8["Time"])
Note11["Time"] = pd.to_datetime(Note11["Time"])

# %%
print(iPhone7plus.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 475 entries, 0 to 474
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Time                  475 non-null    datetime64[ns]
#  1   Current power/SENSOR  475 non-null    object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 7.5+ KB
# None

# %%
iPhone7plus.rename(columns={"Current power/SENSOR": "Current(mA)/SENSOR"}, inplace=True)
iPhone8.rename(columns={"Current power/SENSOR": "Current(mA)/SENSOR"}, inplace=True)
Note11.rename(columns={"Current power/SENSOR": "Current(mA)/SENSOR"}, inplace=True)

# %%
iPhone7plus["Current(mA)/SENSOR"] = iPhone7plus["Current(mA)/SENSOR"].str.replace(
    "[A-Z,a-z]+", "", regex=True
)
iPhone8["Current(mA)/SENSOR"] = iPhone8["Current(mA)/SENSOR"].str.replace(
    "[A-Z,a-z]+", "", regex=True
)
Note11["Current(mA)/SENSOR"] = Note11["Current(mA)/SENSOR"].str.replace(
    "[A-Z,a-z]+", "", regex=True
)

# %%
iPhone7plus
# Out:
#                    Time Current(mA)/SENSOR
# 0   2023-04-10 02:16:30              0.00
# 1   2023-04-10 02:16:40              0.00
# 2   2023-04-10 02:16:50              0.00
# 3   2023-04-10 02:17:00              0.00
# 4   2023-04-10 02:17:10             65.00
# ..                  ...                ...
# 470 2023-04-10 03:34:50             18.00
# 471 2023-04-10 03:35:00             19.00
# 472 2023-04-10 03:35:10             18.00
# 473 2023-04-10 03:35:20             19.00
# 474 2023-04-10 03:35:30             18.00
#
# [475 rows x 2 columns]

# %%
iPhone7plus["Current(mA)/SENSOR"] = iPhone7plus["Current(mA)/SENSOR"].astype('float')
iPhone8["Current(mA)/SENSOR"] = iPhone8["Current(mA)/SENSOR"].astype('float')
Note11["Current(mA)/SENSOR"] = Note11["Current(mA)/SENSOR"].astype('float')

# %%
iPhone7plus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 475 entries, 0 to 474
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Time                475 non-null    datetime64[ns]
#  1   Current(mA)/SENSOR  475 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 7.5 KB

# %%
iPhone7plus
# Out:
#                    Time  Current(mA)/SENSOR
# 0   2023-04-10 02:16:30                 0.0
# 1   2023-04-10 02:16:40                 0.0
# 2   2023-04-10 02:16:50                 0.0
# 3   2023-04-10 02:17:00                 0.0
# 4   2023-04-10 02:17:10                65.0
# ..                  ...                 ...
# 470 2023-04-10 03:34:50                18.0
# 471 2023-04-10 03:35:00                19.0
# 472 2023-04-10 03:35:10                18.0
# 473 2023-04-10 03:35:20                19.0
# 474 2023-04-10 03:35:30                18.0
#
# [475 rows x 2 columns]

# %%
iPhone8.drop(range(0,13),inplace=True)
iPhone8.reset_index(drop=True, inplace=True)

# %%
iPhone7plus.drop(range(0,4),inplace=True)
iPhone7plus.reset_index(drop=True, inplace=True)

# %%
Note11.drop(range(0,15),inplace=True)
Note11.reset_index(drop=True, inplace=True)

# %%
x = iPhone7plus["Time"]
y = iPhone7plus["Current(mA)/SENSOR"]
plt.plot(x, y)
plt.xlabel("Time Stamp")
plt.ylabel("Current (mA)")
# Out:
# Text(0, 0.5, 'Current (mA)')

# %%
x = iPhone8["Time"]
y = iPhone8["Current(mA)/SENSOR"]
plt.plot(x, y)
plt.xlabel("Time Stamp")
plt.ylabel("Current (mA)")
# Out:
# Text(0, 0.5, 'Current (mA)')

# %%
x = Note11["Time"]
y = Note11["Current(mA)/SENSOR"]
plt.plot(x, y)
plt.xlabel("Time Stamp")
plt.ylabel("Current (mA)")
# Out:
# Text(0, 0.5, 'Current (mA)')

# %%
t1 = iPhone7plus.iloc[0,0]
t2 = iPhone8.iloc[0,0]
t3 = Note11.iloc[0,0]

# %%
#iPhone7["time_elasped"] = pd.Timedelta(t2 - iPhone7['Time']).seconds

# %%
time1 = []
for index,row in iPhone7plus.iterrows() :
    time1.append(pd.Timedelta(row['Time']-t1).seconds)

# %%
iPhone7plus["time_elasped(seconds)"] = time1

# %%
time2 = []
for index,row in iPhone8.iterrows() :
    time2.append(pd.Timedelta(row['Time']-t2).seconds)

# %%
iPhone8["time_elasped(seconds)"] = time2

# %%
time3 = []
for index,row in Note11.iterrows() :
    time3.append(pd.Timedelta(row['Time']-t3).seconds)

# %%
Note11["time_elasped(seconds)"] = time3

# %%
iPhone7plus
# Out:
#                    Time  Current(mA)/SENSOR  time_elasped(seconds)
# 0   2023-04-10 02:17:10                65.0                      0
# 1   2023-04-10 02:17:20                59.0                     10
# 2   2023-04-10 02:17:30                57.0                     20
# 3   2023-04-10 02:17:40                56.0                     30
# 4   2023-04-10 02:17:50                53.0                     40
# ..                  ...                 ...                    ...
# 466 2023-04-10 03:34:50                18.0                   4660
# 467 2023-04-10 03:35:00                19.0                   4670
# 468 2023-04-10 03:35:10                18.0                   4680
# 469 2023-04-10 03:35:20                19.0                   4690
# 470 2023-04-10 03:35:30                18.0                   4700
#
# [471 rows x 3 columns]

# %%
Note11["Current(mA)/SENSOR"].max()
# Out:
# 342.0

# %%
iPhone7plus["Current(mA)/SENSOR"].max()
# Out:
# 72.0

# %%
iPhone8["Current(mA)/SENSOR"].max()
# Out:
# 83.0

# %%
iPhone8["Power(mW)"] = iPhone8["Current(mA)/SENSOR"]*5

# %%
iPhone7plus["Power(mW)"] = iPhone7plus["Current(mA)/SENSOR"]*5

# %%
Note11["Power(mW)"] = Note11["Current(mA)/SENSOR"]*5

# %%
Note11.head()
# Out:
#                  Time  Current(mA)/SENSOR  time_elasped(seconds)  Power(mW)
# 0 2023-04-09 04:13:20                95.0                      0      475.0
# 1 2023-04-09 04:13:30                96.0                     10      480.0
# 2 2023-04-09 04:13:40                96.0                     20      480.0
# 3 2023-04-09 04:13:50                95.0                     30      475.0
# 4 2023-04-09 04:14:00                95.0                     40      475.0

# %%
iPhone8.head()
# Out:
#                  Time  Current(mA)/SENSOR  time_elasped(seconds)  Power(mW)
# 0 2023-04-09 09:03:00                18.0                      0       90.0
# 1 2023-04-09 09:03:10                73.0                     10      365.0
# 2 2023-04-09 09:03:20                74.0                     20      370.0
# 3 2023-04-09 09:03:30                74.0                     30      370.0
# 4 2023-04-09 09:03:40                74.0                     40      370.0

# %%
iPhone7plus.head()
# Out:
#                  Time  Current(mA)/SENSOR  time_elasped(seconds)  Power(mW)
# 0 2023-04-10 02:17:10                65.0                      0      325.0
# 1 2023-04-10 02:17:20                59.0                     10      295.0
# 2 2023-04-10 02:17:30                57.0                     20      285.0
# 3 2023-04-10 02:17:40                56.0                     30      280.0
# 4 2023-04-10 02:17:50                53.0                     40      265.0

# %%
df2 = pd.read_csv("dataset/pixel4a.txt", delimiter=",")

# %%
df3 = pd.read_csv("dataset/s21_fe.txt", delimiter=",")

# %%
df2
# Out:
#       voltage(V)   current(mA)   battery_percent  \
# 0          3.768     -2725.832                 1
# 1          3.768     -2940.981                 1
# 2          3.809     -2986.452                 1
# 3          3.809     -2948.000                 1
# 4          3.809     -2886.049                 1
# ...          ...           ...               ...
# 2899       4.462      -604.553                99
# 2900       4.462      -267.334                99
# 2901       4.463      -608.826               100
# 2902       4.463      -597.839               100
# 2903       4.463      -600.586               100
#
#        battery_temperature(Celsius)   remaining_battery_charge(mAh)  \
# 0                              32.5                          153.85
# 1                              32.5                          153.85
# 2                              32.6                          184.62
# 3                              32.6                          184.62
# ...

# %%
df2.tail(10)
# Out:
#       voltage(V)   current(mA)   battery_percent  \
# 2894       4.462      -601.501                99
# 2895       4.462      -601.501                99
# 2896       4.462      -596.619                99
# 2897       4.462      -601.501                99
# 2898       4.462      -596.924                99
# 2899       4.462      -604.553                99
# 2900       4.462      -267.334                99
# 2901       4.463      -608.826               100
# 2902       4.463      -597.839               100
# 2903       4.463      -600.586               100
#
#        battery_temperature(Celsius)   remaining_battery_charge(mAh)  \
# 2894                           36.0                         2984.69
# 2895                           36.0                         2984.69
# 2896                           36.0                         2984.69
# 2897                           36.0                         2984.69
# 2898                           36.0                         2984.69
# ...

# %%
df3.columns
# Out:
# Index(['voltage(V)', 'current(mA)', 'battery_percent',
#        'battery_temperature(Celsius)', 'remaining_battery_charge(mAh)',
#        'battery_capacity(mAh)', 'battery_technology'],
#       dtype='object')

# %%
df3.shape
# Out:
# (4464, 7)

# %%
log1 = pd.read_csv("dataset/s21fe_log.txt", delimiter=" ")

# %%
log1
# Out:
#         date          time useless1 useless2 useless3        main   useless
# 0      04-13  13:05:45.731        I    66@1:     Flow   beginning       NaN
# 1      04-13  13:05:45.732        I   66@18:    Power      source  plugged?
# 2      04-13  13:05:45.750        I   66@11:  Battery  properties       NaN
# 3      04-13  13:05:45.846        I   66@15:     File       write       NaN
# 4      04-13  13:05:45.967        I   66@19:    Delay         NaN       NaN
# ...      ...           ...      ...      ...      ...         ...       ...
# 17854  04-13  14:30:29.691        I   66@11:  Battery  properties       NaN
# 17855  04-13  14:30:29.695        I   66@15:     File       write       NaN
# 17856  04-13  14:30:29.705        I   66@19:    Delay         NaN       NaN
# 17857  04-13  14:30:30.738        I   66@18:    Power      source  plugged?
# 17858  04-13  14:30:30.785        I    66@0:  Stopped          at       end
#
# [17859 rows x 7 columns]

# %%
log1.drop(['useless1', 'useless2','useless3','useless'], axis=1,inplace=True)

# %%
x1 = log1.loc[log1['main'] == 'write']

# %%
x1
# Out:
#         date          time   main
# 3      04-13  13:05:45.846  write
# 7      04-13  13:05:47.004  write
# 11     04-13  13:05:48.050  write
# 15     04-13  13:05:49.085  write
# 19     04-13  13:05:50.110  write
# ...      ...           ...    ...
# 17839  04-13  14:30:25.580  write
# 17843  04-13  14:30:26.603  write
# 17847  04-13  14:30:27.628  write
# 17851  04-13  14:30:28.663  write
# 17855  04-13  14:30:29.695  write
#
# [4464 rows x 3 columns]

# %%
x1.reset_index(drop=True,inplace=True)

# %%
x1
# Out:
#        date          time   main
# 0     04-13  13:05:45.846  write
# 1     04-13  13:05:47.004  write
# 2     04-13  13:05:48.050  write
# 3     04-13  13:05:49.085  write
# 4     04-13  13:05:50.110  write
# ...     ...           ...    ...
# 4459  04-13  14:30:25.580  write
# 4460  04-13  14:30:26.603  write
# 4461  04-13  14:30:27.628  write
# 4462  04-13  14:30:28.663  write
# 4463  04-13  14:30:29.695  write
#
# [4464 rows x 3 columns]

# %%
df3["timestamp"] = x1['time']

# %%
df3
# Out:
#       voltage(V)  current(mA)  battery_percent  battery_temperature(Celsius)  \
# 0           3.36         1595                1                          37.1
# 1           3.36        -1434                1                          37.1
# 2           3.36         -565                1                          37.1
# 3           3.36        -1654                1                          37.1
# 4           3.36         -884                1                          37.1
# ...          ...          ...              ...                           ...
# 4459        4.40         -673              100                          37.7
# 4460        4.40         -659              100                          37.7
# 4461        4.40         -665              100                          37.7
# 4462        4.40         -664              100                          37.7
# 4463        4.40         -661              100                          37.7
#
# ...

# %%
#df3.to_csv('s21fe.csv',index=False)

# %%
#s21fe = pd.read_csv("dataset/s21fe.csv")

# %%
#s21fe.shape

# %%
#s21fe.info()

# %%
s = pd.read_csv("dataset/s21fe.csv")

# %%
s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4464 entries, 0 to 4463
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   voltage(V)                     4464 non-null   float64
#  1   current(mA)                    4464 non-null   int64
#  2   battery_percent                4464 non-null   int64
#  3   battery_temperature(Celsius)   4464 non-null   float64
#  4   remaining_battery_charge(mAh)  4464 non-null   float64
#  5   battery_capacity(mAh)          4464 non-null   int64
#  6   battery_technology             4464 non-null   object
#  7   timestamp                      4464 non-null   object
# dtypes: float64(3), int64(3), object(2)
# memory usage: 279.1+ KB

# %%
s['current(mA)'] = s["current(mA)"].abs()

# %%
s.head()
# Out:
#    voltage(V)  current(mA)  battery_percent  battery_temperature(Celsius)  \
# 0        3.36         1595                1                          37.1
# 1        3.36         1434                1                          37.1
# 2        3.36          565                1                          37.1
# 3        3.36         1654                1                          37.1
# 4        3.36          884                1                          37.1
#
#    remaining_battery_charge(mAh)  battery_capacity(mAh) battery_technology  \
# 0                            0.0                   4370             Li-ion
# 1                            0.0                   4370             Li-ion
# 2                            0.0                   4370             Li-ion
# 3                            0.0                   4370             Li-ion
# 4                            0.0                   4370             Li-ion
#
#       timestamp
# 0  13:05:45.846
# 1  13:05:47.004
# 2  13:05:48.050
# ...

# %%
s["power(W)"] = (s["current(mA)"]/1000) * s["voltage(V)"]

# %%
cols = list(s.columns)

# %%
cols
# Out:
# ['voltage(V)',
#  'current(mA)',
#  'battery_percent',
#  'battery_temperature(Celsius)',
#  'remaining_battery_charge(mAh)',
#  'battery_capacity(mAh)',
#  'battery_technology',
#  'timestamp',
#  'power(W)']

# %%
s_new = s.loc[:, [cols[-2]] + cols[:2] + [cols[-1]] + cols[2:7]]

# %%
s_new.head()
# Out:
#       timestamp  voltage(V)  current(mA)  power(W)  battery_percent  \
# 0  13:05:45.846        3.36         1595   5.35920                1
# 1  13:05:47.004        3.36         1434   4.81824                1
# 2  13:05:48.050        3.36          565   1.89840                1
# 3  13:05:49.085        3.36         1654   5.55744                1
# 4  13:05:50.110        3.36          884   2.97024                1
#
#    battery_temperature(Celsius)  remaining_battery_charge(mAh)  \
# 0                          37.1                            0.0
# 1                          37.1                            0.0
# 2                          37.1                            0.0
# 3                          37.1                            0.0
# 4                          37.1                            0.0
#
#    battery_capacity(mAh) battery_technology
# 0                   4370             Li-ion
# 1                   4370             Li-ion
# ...

# %%
#s_new.to_csv('s21fe_data.csv',index=False)

# %%
a70 = pd.read_csv("dataset/samsung_A70.txt",delimiter=",")

# %%
a70.head()
# Out:
#    voltage(V)  current(mA)  battery_percent  battery_temperature(Celsius)  \
# 0       3.733     -2314454                1                          36.9
# 1       3.492      -140075                1                          36.6
# 2       3.492      -386352                1                          36.6
# 3       3.492      -346374                1                          36.6
# 4       3.492      -382385                1                          36.6
#
#    remaining_battery_charge(mAh)  battery_capacity(mAh) battery_technology
# 0                            0.0                   4400             Li-ion
# 1                            0.0                   4400             Li-ion
# 2                            0.0                   4400             Li-ion
# 3                            0.0                   4400             Li-ion
# 4                            0.0                   4400             Li-ion

# %%
a70["current(mA)"] = a70["current(mA)"].abs()

# %%
a70.head(20)
# Out:
#     voltage(V)  current(mA)  battery_percent  battery_temperature(Celsius)  \
# 0        3.733      2314454                1                          36.9
# 1        3.492       140075                1                          36.6
# 2        3.492       386352                1                          36.6
# 3        3.492       346374                1                          36.6
# 4        3.492       382385                1                          36.6
# 5        3.618       387878                1                          36.6
# 6        3.618       312500                1                          36.6
# 7        3.618       808716                1                          36.6
# 8        3.618       647278                1                          36.6
# 9        3.618       578308                1                          36.6
# 10       3.618       417480                1                          36.6
# ...

# %%
a70.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4686 entries, 0 to 4685
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   voltage(V)                     4686 non-null   float64
#  1   current(mA)                    4686 non-null   int64
#  2   battery_percent                4686 non-null   int64
#  3   battery_temperature(Celsius)   4686 non-null   float64
#  4   remaining_battery_charge(mAh)  4686 non-null   float64
#  5   battery_capacity(mAh)          4686 non-null   int64
#  6   battery_technology             4686 non-null   object
# dtypes: float64(3), int64(3), object(1)
# memory usage: 256.4+ KB

# %%
a70["current(mA)"] = a70["current(mA)"].astype('float')

# %%
import decimal

# %%
a70.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4686 entries, 0 to 4685
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   voltage(V)                     4686 non-null   float64
#  1   current(mA)                    4686 non-null   float64
#  2   battery_percent                4686 non-null   int64
#  3   battery_temperature(Celsius)   4686 non-null   float64
#  4   remaining_battery_charge(mAh)  4686 non-null   float64
#  5   battery_capacity(mAh)          4686 non-null   int64
#  6   battery_technology             4686 non-null   object
# dtypes: float64(4), int64(2), object(1)
# memory usage: 256.4+ KB

# %%
lst = []
for index,row in a70.iterrows():
    lst.append(row["current(mA)"]/1000)

# %%
lst
# Out:
# [2314.454,
#  140.075,
#  386.352,
#  346.374,
#  382.385,
#  387.878,
#  312.5,
#  808.716,
#  647.278,
#  578.308,
#  417.48,
#  361.938,
#  362.549,
#  2113.038,
#  3355.715,
#  3811.037,
#  4004.519,
#  4007.876,
#  3841.555,
#  4004.519,
#  1766.053,
#  1279.908,
#  1737.366,
#  1887.208,
#  1848.451,
#  1926.27,
#  2013.551,
#  1864.93,
#  1933.9,
#  1955.567,
#  1961.976,
#  1890.565,
#  1778.565,
#  1978.761,
#  1968.69,
#  1961.366,
#  1864.93,
#  1928.101,
#  1991.578,
#  1851.502,
#  1970.826,
#  1949.769,
#  1946.717,
#  1906.739,
#  1875.916,
#  1919.557,
#  1875.916,
#  1826.478,
#  1896.974,
#  1902.162,
#  1871.644,
#  1887.513,
#  1806.947,
#  1738.892,
#  1853.028,
#  1839.906,
#  1632.081,
#  1853.028,
#  2434.999,
#  3995.364,
#  4002.688,
#  4011.538,
#  4032.29,
#  4032.595,
#  4038.088,
#  4042.971,
#  4033.816,
#  4041.445,
#  4035.952,
#  4033.511,
#  4035.647,
#  4040.225,
#  4029.849,
#  4033.511,
#  4038.699,
#  4033.206,
#  4037.173,
#  4026.797,
# ...

# %%
a70["current(mA)"] = lst

# %%
a70.head(20)
# Out:
#     voltage(V)  current(mA)  battery_percent  battery_temperature(Celsius)  \
# 0        3.733     2314.454                1                          36.9
# 1        3.492      140.075                1                          36.6
# 2        3.492      386.352                1                          36.6
# 3        3.492      346.374                1                          36.6
# 4        3.492      382.385                1                          36.6
# 5        3.618      387.878                1                          36.6
# 6        3.618      312.500                1                          36.6
# 7        3.618      808.716                1                          36.6
# 8        3.618      647.278                1                          36.6
# 9        3.618      578.308                1                          36.6
# 10       3.618      417.480                1                          36.6
# ...

# %%
log2 = pd.read_csv("dataset/samsungA70-log.txt",delimiter=" ")

# %%
log2.head()
# Out:
#     date          time useless1 useless2 useless3        main   useless
# 0  04-13  17:12:33.880        I     1@1:     Flow   beginning       NaN
# 1  04-13  17:12:33.893        I    1@18:    Power      source  plugged?
# 2  04-13  17:12:33.908        I    1@11:  Battery  properties       NaN
# 3  04-13  17:12:33.937        I    1@15:     File       write       NaN
# 4  04-13  17:12:34.018        I    1@19:    Delay         NaN       NaN

# %%
log2.drop(['useless1', 'useless2','useless3','useless'], axis=1,inplace=True)

# %%
x2 = log2.loc[log2['main'] == 'write']
x2.reset_index(drop=True,inplace=True)

# %%
a70.shape
# Out:
# (4686, 7)

# %%
x2.shape
# Out:
# (4686, 3)

# %%
a70["timestamp"] = x2['time']

# %%
a70.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4686 entries, 0 to 4685
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   voltage(V)                     4686 non-null   float64
#  1   current(mA)                    4686 non-null   float64
#  2   battery_percent                4686 non-null   int64
#  3   battery_temperature(Celsius)   4686 non-null   float64
#  4   remaining_battery_charge(mAh)  4686 non-null   float64
#  5   battery_capacity(mAh)          4686 non-null   int64
#  6   battery_technology             4686 non-null   object
#  7   timestamp                      4686 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 293.0+ KB

# %%
import numpy as np

# %%
a70["current(mA)"] = a70['current(mA)'].apply(np.floor)

# %%
a70.head(10)
# Out:
#    voltage(V)  current(mA)  battery_percent  battery_temperature(Celsius)  \
# 0       3.733       2314.0                1                          36.9
# 1       3.492        140.0                1                          36.6
# 2       3.492        386.0                1                          36.6
# 3       3.492        346.0                1                          36.6
# 4       3.492        382.0                1                          36.6
# 5       3.618        387.0                1                          36.6
# 6       3.618        312.0                1                          36.6
# 7       3.618        808.0                1                          36.6
# 8       3.618        647.0                1                          36.6
# 9       3.618        578.0                1                          36.6
#
#    remaining_battery_charge(mAh)  battery_capacity(mAh) battery_technology  \
# 0                            0.0                   4400             Li-ion
# ...

# %%
a70["current(mA)"] = a70["current(mA)"].astype('int64')

# %%
a70.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4686 entries, 0 to 4685
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   voltage(V)                     4686 non-null   float64
#  1   current(mA)                    4686 non-null   int64
#  2   battery_percent                4686 non-null   int64
#  3   battery_temperature(Celsius)   4686 non-null   float64
#  4   remaining_battery_charge(mAh)  4686 non-null   float64
#  5   battery_capacity(mAh)          4686 non-null   int64
#  6   battery_technology             4686 non-null   object
#  7   timestamp                      4686 non-null   object
# dtypes: float64(3), int64(3), object(2)
# memory usage: 293.0+ KB

# %%
a70["power(W)"] = (a70["current(mA)"]/1000) * a70["voltage(V)"]

# %%
cols2 = list(a70.columns)
a70_new = a70.loc[:, [cols2[-2]] + cols2[:2] + [cols2[-1]] + cols2[2:7]]

# %%
a70_new.head()
# Out:
#       timestamp  voltage(V)  current(mA)  power(W)  battery_percent  \
# 0  17:12:33.937       3.733         2314  8.638162                1
# 1  17:12:35.074       3.492          140  0.488880                1
# 2  17:12:36.137       3.492          386  1.347912                1
# 3  17:12:37.183       3.492          346  1.208232                1
# 4  17:12:38.228       3.492          382  1.333944                1
#
#    battery_temperature(Celsius)  remaining_battery_charge(mAh)  \
# 0                          36.9                            0.0
# 1                          36.6                            0.0
# 2                          36.6                            0.0
# 3                          36.6                            0.0
# 4                          36.6                            0.0
#
#    battery_capacity(mAh) battery_technology
# 0                   4400             Li-ion
# 1                   4400             Li-ion
# ...

# %%
#a70_new.to_csv('dataset/samsung_a70.csv',index=False)

# %%
pixel6a = pd.read_csv("dataset/pixel6a.txt",delimiter=",")

# %%
log3 = pd.read_csv("dataset/pixel6a-log.txt",delimiter=" ")

# %%
log3
# Out:
#         date          time useless1 useless2 useless3        main   useless
# 0      04-13  19:30:08.474        I     2@1:     Flow   beginning       NaN
# 1      04-13  19:30:08.475        I    2@18:    Power      source  plugged?
# 2      04-13  19:30:08.475        I    2@11:  Battery  properties       NaN
# 3      04-13  19:30:08.484        I    2@15:     File       write       NaN
# 4      04-13  19:30:08.504        I    2@19:    Delay         NaN       NaN
# ...      ...           ...      ...      ...      ...         ...       ...
# 13326  04-13  21:27:21.193        I    2@11:  Battery  properties       NaN
# 13327  04-13  21:27:21.195        I    2@15:     File       write       NaN
# 13328  04-13  21:27:21.203        I    2@19:    Delay         NaN       NaN
# 13329  04-13  21:27:22.211        I    2@18:    Power      source  plugged?
# 13330  04-13  21:27:22.212        I     2@0:  Stopped          at       end
#
# [13331 rows x 7 columns]

# %%
log3.drop(['useless1', 'useless2','useless3','useless'], axis=1,inplace=True)
x3 = log3.loc[log2['main'] == 'write']
x3.reset_index(drop=True,inplace=True)

# %%
x3.head()
# Out:
#     date          time   main
# 0  04-13  19:30:08.484  write
# 1  04-13  19:30:09.527  write
# 2  04-13  19:30:10.576  write
# 3  04-13  19:30:11.622  write
# 4  04-13  19:30:12.652  write

# %%
pixel6a["current(mA)"] = pixel6a["current(mA)"].abs()

# %%
pixel6a["timestamp"] = x3['time']

# %%
pixel6a.head()
# Out:
#    voltage(V)  current(mA)  battery_percent  battery_temperature(Celsius)  \
# 0       3.314     3786.250                1                          34.1
# 1       3.647     3979.375                1                          34.1
# 2       3.647     3987.812                1                          34.1
# 3       3.647     3980.625                1                          34.1
# 4       3.647     3983.437                1                          34.1
#
#    remaining_battery_charge(mAh)  battery_capacity(mAh) battery_technology  \
# 0                            170                   4410             Li-ion
# 1                            172                   4410             Li-ion
# 2                            174                   4410             Li-ion
# 3                            174                   4410             Li-ion
# 4                            176                   4410             Li-ion
#
#       timestamp
# 0  19:30:08.484
# 1  19:30:09.527
# 2  19:30:10.576
# ...

# %%
pixel6a["power(W)"] = (pixel6a["current(mA)"]/1000) * pixel6a["voltage(V)"]

# %%
pixel6a.head()
# Out:
#    voltage(V)  current(mA)  battery_percent  battery_temperature(Celsius)  \
# 0       3.314     3786.250                1                          34.1
# 1       3.647     3979.375                1                          34.1
# 2       3.647     3987.812                1                          34.1
# 3       3.647     3980.625                1                          34.1
# 4       3.647     3983.437                1                          34.1
#
#    remaining_battery_charge(mAh)  battery_capacity(mAh) battery_technology  \
# 0                            170                   4410             Li-ion
# 1                            172                   4410             Li-ion
# 2                            174                   4410             Li-ion
# 3                            174                   4410             Li-ion
# 4                            176                   4410             Li-ion
#
#       timestamp   power(W)
# 0  19:30:08.484  12.547633
# ...

# %%
pixel6a["current(mA)"] = pixel6a['current(mA)'].apply(np.floor)

# %%
pixel6a.head()
# Out:
#    voltage(V)  current(mA)  battery_percent  battery_temperature(Celsius)  \
# 0       3.314       3786.0                1                          34.1
# 1       3.647       3979.0                1                          34.1
# 2       3.647       3987.0                1                          34.1
# 3       3.647       3980.0                1                          34.1
# 4       3.647       3983.0                1                          34.1
#
#    remaining_battery_charge(mAh)  battery_capacity(mAh) battery_technology  \
# 0                            170                   4410             Li-ion
# 1                            172                   4410             Li-ion
# 2                            174                   4410             Li-ion
# 3                            174                   4410             Li-ion
# 4                            176                   4410             Li-ion
#
#       timestamp   power(W)
# 0  19:30:08.484  12.547633
# ...

# %%
pixel6a["current(mA)"] = pixel6a["current(mA)"].astype('int64')

# %%
pixel6a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3332 entries, 0 to 3331
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   voltage(V)                     3332 non-null   float64
#  1   current(mA)                    3332 non-null   int64
#  2   battery_percent                3332 non-null   int64
#  3   battery_temperature(Celsius)   3332 non-null   float64
#  4   remaining_battery_charge(mAh)  3332 non-null   int64
#  5   battery_capacity(mAh)          3332 non-null   int64
#  6   battery_technology             3332 non-null   object
#  7   timestamp                      3332 non-null   object
#  8   power(W)                       3332 non-null   float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 234.4+ KB

# %%
cols3 = list(pixel6a.columns)
pixel6a_new = pixel6a.loc[:, [cols3[-2]] + cols3[:2] + [cols3[-1]] + cols3[2:7]]

# %%
pixel6a_new.head()
# Out:
#       timestamp  voltage(V)  current(mA)   power(W)  battery_percent  \
# 0  19:30:08.484       3.314         3786  12.547633                1
# 1  19:30:09.527       3.647         3979  14.512781                1
# 2  19:30:10.576       3.647         3987  14.543550                1
# 3  19:30:11.622       3.647         3980  14.517339                1
# 4  19:30:12.652       3.647         3983  14.527595                1
#
#    battery_temperature(Celsius)  remaining_battery_charge(mAh)  \
# 0                          34.1                            170
# 1                          34.1                            172
# 2                          34.1                            174
# 3                          34.1                            174
# 4                          34.1                            176
#
#    battery_capacity(mAh) battery_technology
# 0                   4410             Li-ion
# 1                   4410             Li-ion
# ...

# %%
pixel6a_new.to_csv('dataset/pixel_6a.csv',index=False)
